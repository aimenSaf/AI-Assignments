# %% [markdown]
# <a href="https://colab.research.google.com/github/aimenSaf/AI-Assignments/blob/main/AlphaBetaPruning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#working aplha beta pruning
#Q1
ALPHA, BETA = float('-inf'), float('inf')
player, opponent = 'x', 'o'


def isMovesLeft(board):  #finding empty cells
    for i in range(3):
        for j in range(3):
            if board[i][j] == '_':
                return True
    return False


def evaluate(board):
    for row in range(3):
        if board[row][0] == board[row][1] == board[row][2] and board[row][0] != '_':
            return 10 if board[row][0] == 'x' else -10

    for col in range(3):
        if board[0][col] == board[1][col] == board[2][col] and board[0][col] != '_':
            return 10 if board[0][col] == 'x' else -10

    if board[0][0] == board[1][1] == board[2][2] and board[0][0] != '_':
        return 10 if board[0][0] == 'x' else -10

    if board[0][2] == board[1][1] == board[2][0] and board[0][2] != '_':
        return 10 if board[0][2] == 'x' else -10

    return 0  # If draw or game still ongoing


def minimax(board, depth, isMax, alpha, beta):
    score = evaluate(board)

    if score == 10 or score == -10:
        return score

    if not isMovesLeft(board):
        return 0

    if depth == 0:
        return 0

    if isMax:
        best = float('-inf')
        for i in range(3):
            for j in range(3):
                if board[i][j] == '_':
                    board[i][j] = player
                    best = max(best, minimax(board, depth - 1, not isMax, alpha, beta))
                    alpha = max(alpha, best)
                    board[i][j] = '_'
                    if beta <= alpha:
                        break
        return best
    else:
        best = float('inf')
        for i in range(3):
            for j in range(3):
                if board[i][j] == '_':
                    board[i][j] = opponent
                    best = min(best, minimax(board, depth - 1, not isMax, alpha, beta))
                    beta = min(beta, best)
                    board[i][j] = '_'
                    if beta <= alpha:
                        break
        return best


def findBestMove(board):  #finding the best move for the current player
    bestVal = float('-inf')
    bestMove = (-1, -1)

    for i in range(3):
        for j in range(3):
            if board[i][j] == '_':
                board[i][j] = player
                moveVal = minimax(board, 8, False, ALPHA, BETA)  # rescursion
                board[i][j] = '_'
                if moveVal > bestVal:
                    bestMove = (i, j)
                    bestVal = moveVal

    print("The value of the best Move is:", bestVal)
    return bestMove


def initialize_board():
    """ Initialize an empty Tic-Tac-Toe board. """
    return [['_', '_', '_'] for _ in range(3)]


def print_board(board):
    """ Print the current state of the board. """
    for row in board:
        print(' '.join(row))


def is_valid_move(board, row, col):
    """ Check if the given move is valid. """
    return 0 <= row < 3 and 0 <= col < 3 and board[row][col] == '_'


# Initialize an empty board
board = initialize_board()
current_player = player

# Play until the game is over
while isMovesLeft(board):
    print_board(board)

    if current_player == player:
        print("Player 'x' turn")
        while True:
            try:
                row = int(input("Enter row (0, 1, 2): "))
                col = int(input("Enter column (0, 1, 2): "))
                if is_valid_move(board, row, col):
                    board[row][col] = player
                    break
                else:
                    print("Invalid move. Try again.")
            except ValueError:
                print("Invalid input. Please enter a number.")
    else:
        print("Player 'o' turn")
        row, col = findBestMove(board)
        board[row][col] = opponent

    # Check if current player wins
    if evaluate(board) == 10:
        print_board(board)
        print("Player 'x' wins!")
        break
    elif evaluate(board) == -10:
        print_board(board)
        print("Player 'o' wins!")
        break


    current_player = opponent if current_player == player else player   #switching players

# If no one wins, it's a draw
if not isMovesLeft(board):
    print_board(board)
    print("It's a draw!")

# %%
#q2 part 1 without pruining
player, opponent = 'x', 'o'


def isMovesLeft(board):   #checking if moves are left
    for i in range(3):
        for j in range(3):
            if board[i][j] == '_':
                return True
    return False


def evaluate(board):
    for row in range(3):
        if board[row][0] == board[row][1] == board[row][2] and board[row][0] != '_':
            return 10 if board[row][0] == 'x' else -10

    for col in range(3):
        if board[0][col] == board[1][col] == board[2][col] and board[0][col] != '_':
            return 10 if board[0][col] == 'x' else -10

    if board[0][0] == board[1][1] == board[2][2] and board[0][0] != '_':
        return 10 if board[0][0] == 'x' else -10

    if board[0][2] == board[1][1] == board[2][0] and board[0][2] != '_':
        return 10 if board[0][2] == 'x' else -10

    return 0  # If draw or game still ongoing


def minimax(board, depth, isMax, nodes_count):
    nodes_count[0] += 1  # node incremented for each call of player

    score = evaluate(board)

    if score == 10 or score == -10:
        return score

    if not isMovesLeft(board):
        return 0

    if depth == 0:
        return 0

    if isMax:
        best = float('-inf')
        for i in range(3):
            for j in range(3):
                if board[i][j] == '_':
                    board[i][j] = player
                    best = max(best, minimax(board, depth - 1, not isMax, nodes_count))
                    board[i][j] = '_'
        return best
    else:
        best = float('inf')
        for i in range(3):
            for j in range(3):
                if board[i][j] == '_':
                    board[i][j] = opponent
                    best = min(best, minimax(board, depth - 1, not isMax, nodes_count))
                    board[i][j] = '_'
        return best


def initialize_board():
    return [['_', '_', '_'] for _ in range(3)]   #printing board


def TicTacToe(num_runs, depth):
    total_nodes = 0
    nodes_per_run = []

    for run in range(1, num_runs + 1):
        board = initialize_board()
        nodes_count = [0]  # List to store node count (mutable for passing by reference)
        minimax(board, depth, True, nodes_count)
        nodes_per_run.append(nodes_count[0])
        total_nodes += nodes_count[0]
        print(f"Nodes evaluated in run {run}: {nodes_count[0]}")

    avg_nodes = total_nodes / num_runs
    print(f"Average number of nodes evaluated over {num_runs} runs with depth {depth}: {avg_nodes}")
    return nodes_per_run


# Run three games with a specified depth
num_runs = 3
search_depth = 8
node_counts = TicTacToe(num_runs, search_depth)
# Out:
# Nodes evaluated in run 1: 422074
# Nodes evaluated in run 2: 422074
# Nodes evaluated in run 3: 422074
# Average number of nodes evaluated over 3 runs with depth 8: 422074.0

# %%
#q2 part 1 with pruing:
ALPHA, BETA = float('-inf'), float('inf')
player, opponent = 'x', 'o'


def isMovesLeft(board):
    for i in range(3):
        for j in range(3):
            if board[i][j] == '_':
                return True
    return False


def evaluate(board):
    for row in range(3):
        if board[row][0] == board[row][1] == board[row][2] and board[row][0] != '_':
            return 10 if board[row][0] == 'x' else -10

    for col in range(3):
        if board[0][col] == board[1][col] == board[2][col] and board[0][col] != '_':
            return 10 if board[0][col] == 'x' else -10

    if board[0][0] == board[1][1] == board[2][2] and board[0][0] != '_':
        return 10 if board[0][0] == 'x' else -10

    if board[0][2] == board[1][1] == board[2][0] and board[0][2] != '_':
        return 10 if board[0][2] == 'x' else -10

    return 0  # If draw or game still ongoing


def minimax_alpha_beta(board, depth, isMax, alpha, beta, nodes_count):
    nodes_count[0] += 1  # Increment node count for each call to minimax

    score = evaluate(board)

    if score == 10 or score == -10:
        return score

    if not isMovesLeft(board):
        return 0

    if depth == 0:
        return 0

    if isMax:
        best = float('-inf')
        for i in range(3):
            for j in range(3):
                if board[i][j] == '_':
                    board[i][j] = player
                    best = max(best, minimax_alpha_beta(board, depth - 1, not isMax, alpha, beta, nodes_count))
                    alpha = max(alpha, best)
                    board[i][j] = '_'
                    if beta <= alpha:
                        break
        return best
    else:
        best = float('inf')
        for i in range(3):
            for j in range(3):
                if board[i][j] == '_':
                    board[i][j] = opponent
                    best = min(best, minimax_alpha_beta(board, depth - 1, not isMax, alpha, beta, nodes_count))
                    beta = min(beta, best)
                    board[i][j] = '_'
                    if beta <= alpha:
                        break
        return best


def findBestMove_alpha_beta(board):   #best move found
    bestVal = float('-inf')
    bestMove = (-1, -1)

    for i in range(3):
        for j in range(3):
            if board[i][j] == '_':
                board[i][j] = player
                moveVal = minimax_alpha_beta(board, 8, False, ALPHA, BETA, [0])  # Adjust depth as needed
                board[i][j] = '_'
                if moveVal > bestVal:
                    bestMove = (i, j)
                    bestVal = moveVal

    print("The value of the best Move is:", bestVal)
    return bestMove


def initialize_board():
    return [['_', '_', '_'] for _ in range(3)]


def print_board(board):  #board current state printed
    for row in board:
        print(' '.join(row))


def is_valid_move(board, row, col):
    """ Check if the given move is valid. """
    return 0 <= row < 3 and 0 <= col < 3 and board[row][col] == '_'


def alpha_beta(num_runs, depth):
    total_nodes = 0
    nodes_per_run = []

    for run in range(1, num_runs + 1):
        board = initialize_board()
        nodes_count = [0]  # List to store node count (mutable for passing by reference)
        minimax_alpha_beta(board, depth, True, ALPHA, BETA, nodes_count)
        nodes_per_run.append(nodes_count[0])
        total_nodes += nodes_count[0]
        print(f"Nodes evaluated in run {run}: {nodes_count[0]}")

    avg_nodes = total_nodes / num_runs
    print(f"Average number of nodes evaluated over {num_runs} runs with depth {depth}: {avg_nodes}")
    return nodes_per_run


# Run three games with alpha-beta pruning and a specified depth
num_runs = 3
search_depth = 8
node_counts_alpha_beta = alpha_beta(num_runs, search_depth)
# Out:
# Nodes evaluated in run 1: 37182
# Nodes evaluated in run 2: 37182
# Nodes evaluated in run 3: 37182
# Average number of nodes evaluated over 3 runs with depth 8: 37182.0

# %%
#q2 part 2 alpha beta threads
import threading
import time

ALPHA, BETA = float('-inf'), float('inf')
player, opponent = 'x', 'o'


def isMovesLeft(board):
    for i in range(3):
        for j in range(3):
            if board[i][j] == '_':
                return True
    return False


def evaluate(board):
    for row in range(3):
        if board[row][0] == board[row][1] == board[row][2] and board[row][0] != '_':
            return 10 if board[row][0] == 'x' else -10

    for col in range(3):
        if board[0][col] == board[1][col] == board[2][col] and board[0][col] != '_':
            return 10 if board[0][col] == 'x' else -10

    if board[0][0] == board[1][1] == board[2][2] and board[0][0] != '_':
        return 10 if board[0][0] == 'x' else -10

    if board[0][2] == board[1][1] == board[2][0] and board[0][2] != '_':
        return 10 if board[0][2] == 'x' else -10

    return 0  # If draw or game still ongoing


def minimax_alpha_beta(board, depth, isMax, alpha, beta, node_count, node_times):
    score = evaluate(board)
    node_count[0] += 1

    if score == 10 or score == -10:
        return score

    if not isMovesLeft(board):
        return 0

    if depth == 0:
        return 0

    start_time = time.time()
    if isMax:
        best = float('-inf')
        for i in range(3):
            for j in range(3):
                if board[i][j] == '_':
                    board[i][j] = player
                    best = max(best, minimax_alpha_beta(board, depth - 1, not isMax, alpha, beta, node_count, node_times))
                    alpha = max(alpha, best)
                    board[i][j] = '_'
                    if beta <= alpha:
                        break
    else:
        best = float('inf')
        for i in range(3):
            for j in range(3):
                if board[i][j] == '_':
                    board[i][j] = opponent
                    best = min(best, minimax_alpha_beta(board, depth - 1, not isMax, alpha, beta, node_count, node_times))
                    beta = min(beta, best)
                    board[i][j] = '_'
                    if beta <= alpha:
                        break

    end_time = time.time()
    elapsed_time = end_time - start_time
    node_times.append(elapsed_time)
    return best


def findBestMove(board):
    bestVal = float('-inf')
    bestMove = (-1, -1)
    node_count = [0]  # number of nodes evaluated
    node_times = []   # time taken to evaluate

    def search_branch(is_max, alpha, beta):
        nonlocal bestVal, bestMove
        for i in range(3):
            for j in range(3):
                if board[i][j] == '_':
                    board[i][j] = player if is_max else opponent
                    moveVal = minimax_alpha_beta(board, 8, not is_max, alpha, beta, node_count, node_times)
                    board[i][j] = '_'
                    if (is_max and moveVal > bestVal) or (not is_max and moveVal < bestVal):
                        bestMove = (i, j)
                        bestVal = moveVal
                    alpha = max(alpha, bestVal) if is_max else alpha
                    beta = min(beta, bestVal) if not is_max else beta
                    if beta <= alpha:
                        break

    # two threads, one for maximizing player 'x' and one for minimizing player 'o'
    thread1 = threading.Thread(target=search_branch, args=(True, ALPHA, BETA))
    thread2 = threading.Thread(target=search_branch, args=(False, ALPHA, BETA))


    start_time = time.time()
    thread1.start()
    thread2.start()

    thread1.join()
    thread2.join()

    end_time = time.time()
    elapsed_time = end_time - start_time
    node_times.append(elapsed_time)

    avg_nodes = node_count[0] / 2

    avg_time = sum(node_times) / len(node_times)

    print("Parallel alpha-beta pruning took {:.4f} seconds".format(elapsed_time))
    print("Average number of nodes evaluated:", avg_nodes)
    print("Average time taken per node:", avg_time)
    print("The value of the best Move is:", bestVal)
    return bestMove


def initialize_board():
    return [['_', '_', '_'] for _ in range(3)]


def print_board(board):
    for row in board:
        print(' '.join(row))


def is_valid_move(board, row, col):
    return 0 <= row < 3 and 0 <= col < 3 and board[row][col] == '_'


# Initialize an empty board
board = initialize_board()
current_player = player

while isMovesLeft(board):  #game is played until moves are finished
    print_board(board)

    if current_player == player:
        print("Player 'x' turn")
        while True:
            try:
                row = int(input("Enter row (0, 1, 2): "))
                col = int(input("Enter column (0, 1, 2): "))
                if is_valid_move(board, row, col):
                    board[row][col] = player
                    break
                else:
                    print("Invalid move. Try again.")
            except ValueError:
                print("Invalid input. Please enter a number.")
    else:
        print("Player 'o' turn")
        row, col = findBestMove(board)  #
        board[row][col] = opponent

    # Check if current player wins
    if evaluate(board) == 10:
        print_board(board)
        print("Player 'x' wins!")
        break
    elif evaluate(board) == -10:
        print_board(board)
        print("Player 'o' wins!")
        break

   #switching players
    current_player = opponent if current_player == player else player

# If no one wins, it's a draw
if not isMovesLeft(board):
    print_board(board)
    print("It's a draw!")

# %%
import time

ALPHA, BETA = float('-inf'), float('inf')
player, opponent = 'x', 'o'


def isMovesLeft(board):
    for i in range(3):
        for j in range(3):
            if board[i][j] == '_':
                return True
    return False


def evaluate(board):
    for row in range(3):
        if board[row][0] == board[row][1] == board[row][2] and board[row][0] != '_':
            return 10 if board[row][0] == 'x' else -10

    for col in range(3):
        if board[0][col] == board[1][col] == board[2][col] and board[0][col] != '_':
            return 10 if board[0][col] == 'x' else -10

    if board[0][0] == board[1][1] == board[2][2] and board[0][0] != '_':
        return 10 if board[0][0] == 'x' else -10

    if board[0][2] == board[1][1] == board[2][0] and board[0][2] != '_':
        return 10 if board[0][2] == 'x' else -10

    return 0  # If draw or game still ongoing


def minimax(board, depth, isMax, alpha, beta, node_count, node_times):
    score = evaluate(board)
    node_count[0] += 1

    if score == 10 or score == -10:
        return score

    if not isMovesLeft(board):
        return 0

    if depth == 0:
        return 0

    start_time = time.time()
    if isMax:
        best = float('-inf')
        for i in range(3):
            for j in range(3):
                if board[i][j] == '_':
                    board[i][j] = player
                    best = max(best, minimax(board, depth - 1, not isMax, alpha, beta, node_count, node_times))
                    alpha = max(alpha, best)
                    board[i][j] = '_'
                    if beta <= alpha:
                        break
    else:
        best = float('inf')
        for i in range(3):
            for j in range(3):
                if board[i][j] == '_':
                    board[i][j] = opponent
                    best = min(best, minimax(board, depth - 1, not isMax, alpha, beta, node_count, node_times))
                    beta = min(beta, best)
                    board[i][j] = '_'
                    if beta <= alpha:
                        break

    end_time = time.time()
    elapsed_time = end_time - start_time
    node_times.append(elapsed_time)
    return best


def findBestMove(board):
    bestVal = float('-inf')
    bestMove = (-1, -1)
    node_count = [0]  # Number of nodes evaluated
    node_times = []   # Time taken for each node evaluation

    for i in range(3):
        for j in range(3):
            if board[i][j] == '_':
                board[i][j] = player
                moveVal = minimax(board, 8, False, ALPHA, BETA, node_count, node_times)
                board[i][j] = '_'
                if moveVal > bestVal:
                    bestMove = (i, j)
                    bestVal = moveVal

    avg_nodes = node_count[0] / 9  # Average number of nodes evaluated
    avg_time = sum(node_times) / len(node_times)  # Average time taken per node

    print("Average number of nodes evaluated:", avg_nodes)
    print("Average time taken per node:", avg_time)
    print("The value of the best Move is:", bestVal)
    return bestMove


def initialize_board():
    """ Initialize an empty Tic-Tac-Toe board. """
    return [['_', '_', '_'] for _ in range(3)]


def print_board(board):
    """ Print the current state of the board. """
    for row in board:
        print(' '.join(row))


def is_valid_move(board, row, col):
    """ Check if the given move is valid. """
    return 0 <= row < 3 and 0 <= col < 3 and board[row][col] == '_'


# Conduct three runs
for _ in range(3):
    board = initialize_board()
    current_player = player

    while isMovesLeft(board):
        print_board(board)

        if current_player == player:
            print("Player 'x' turn")
            while True:
                try:
                    row = int(input("Enter row (0, 1, 2): "))
                    col = int(input("Enter column (0, 1, 2): "))
                    if is_valid_move(board, row, col):
                        board[row][col] = player
                        break
                    else:
                        print("Invalid move. Try again.")
                except ValueError:
                    print("Invalid input. Please enter a number.")
        else:
            print("Player 'o' turn")
            row, col = findBestMove(board)
            board[row][col] = opponent

        if evaluate(board) == 10:
            print_board(board)
            print("Player 'x' wins!")
            break
        elif evaluate(board) == -10:
            print_board(board)
            print("Player 'o' wins!")
            break

        current_player = opponent if current_player == player else player

    # If no one wins, it's a draw
    if not isMovesLeft(board):
        print_board(board)
        print("It's a draw!")

# %%
import time

ALPHA, BETA = float('-inf'), float('inf')
player, opponent = 'x', 'o'

def isMovesLeft(board):
    for i in range(3):
        for j in range(3):
            if board[i][j] == '_':
                return True
    return False

def evaluate(board):
    for row in range(3):
        if board[row][0] == board[row][1] == board[row][2] and board[row][0] != '_':
            return 10 if board[row][0] == 'x' else -10

    for col in range(3):
        if board[0][col] == board[1][col] == board[2][col] and board[0][col] != '_':
            return 10 if board[0][col] == 'x' else -10

    if board[0][0] == board[1][1] == board[2][2] and board[0][0] != '_':
        return 10 if board[0][0] == 'x' else -10

    if board[0][2] == board[1][1] == board[2][0] and board[0][2] != '_':
        return 10 if board[0][2] == 'x' else -10

    return 0

def minimax(board, depth, isMax, alpha, beta, node_count):
    score = evaluate(board)
    node_count[0] += 1

    if score == 10 or score == -10:
        return score

    if not isMovesLeft(board):
        return 0

    if depth == 0:
        return 0

    if isMax:
        best = float('-inf')
        for i in range(3):
            for j in range(3):
                if board[i][j] == '_':
                    board[i][j] = player
                    best = max(best, minimax(board, depth - 1, False, alpha, beta, node_count))
                    alpha = max(alpha, best)
                    board[i][j] = '_'
                    if beta <= alpha:
                        break
        return best
    else:
        best = float('inf')
        for i in range(3):
            for j in range(3):
                if board[i][j] == '_':
                    board[i][j] = opponent
                    best = min(best, minimax(board, depth - 1, True, alpha, beta, node_count))
                    beta = min(beta, best)
                    board[i][j] = '_'
                    if beta <= alpha:
                        break
        return best

def findBestMove(board, node_counts):
    bestVal = float('-inf')
    bestMove = (-1, -1)
    node_count = [0]

    for i in range(3):
        for j in range(3):
            if board[i][j] == '_':
                board[i][j] = player
                moveVal = minimax(board, 8, False, ALPHA, BETA, node_count)
                board[i][j] = '_'
                if moveVal > bestVal:
                    bestMove = (i, j)
                    bestVal = moveVal

    node_counts.append(node_count[0])

    print("The value of the best Move is:", bestVal)
    return bestMove

def initialize_board():
    return [['_', '_', '_'] for _ in range(3)]

def print_board(board):
    for row in board:
        print(' '.join(row))

def is_valid_move(board, row, col):
    return 0 <= row < 3 and 0 <= col < 3 and board[row][col] == '_'

board = initialize_board()
current_player = player
node_counts = []

for game_number in range(3):
    print(f"Game {game_number + 1}:")

    while isMovesLeft(board):
        print_board(board)

        if current_player == player:
            print("Player 'x' turn")
            while True:
                try:
                    row = int(input("Enter row (0, 1, 2): "))
                    col = int(input("Enter column (0, 1, 2): "))
                    if is_valid_move(board, row, col):
                        board[row][col] = player
                        break
                    else:
                        print("Invalid move. Try again.")
                except ValueError:
                    print("Invalid input. Please enter a number.")
        else:
            print("Player 'o' turn")
            row, col = findBestMove(board, node_counts)
            board[row][col] = opponent

        if evaluate(board) == 10:
            print_board(board)
            print("Player 'x' wins!")
            break
        elif evaluate(board) == -10:
            print_board(board)
            print("Player 'o' wins!")
            break

        current_player = opponent if current_player == player else player

    if not isMovesLeft(board):
        print_board(board)
        print("It's a draw!")

    print(f"Nodes evaluated in Game {game_number + 1}: {node_counts[-1]}")
    board = initialize_board()
    current_player = player

avg_nodes = sum(node_counts) / len(node_counts)
print("Average number of nodes evaluated per game:", avg_nodes)
0
